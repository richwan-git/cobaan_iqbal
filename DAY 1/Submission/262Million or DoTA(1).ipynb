# %%
import numpy as np
import pandas as pd

# %%
myfile = 'contacts.json'
df = pd.read_json(myfile)

# %%
df.head()
# Out:
#    Id               Email         Phone  Contacts                    OrderId
# 0   0      gkzAbIy@qq.com                       1
# 1   1                      329442681752         4  vDDJJcxfLtSfkooPhbYnJdxov
# 2   2                        9125983679         0
# 3   3  mdllpYmE@gmail.com                       0  bHquEnCbbsGLqllwryxPsNOxa
# 4   4                         300364407         2

# %%
df
# Out:
#             Id                Email         Phone  Contacts  \
# 0            0       gkzAbIy@qq.com                       1
# 1            1                       329442681752         4
# 2            2                         9125983679         0
# 3            3   mdllpYmE@gmail.com                       0
# 4            4                          300364407         2
# ...        ...                  ...           ...       ...
# 499995  499995                        10072395382         2
# 499996  499996                       571709661031         4
# 499997  499997                         4541459979         2
# 499998  499998  RzSDsyH@hotmail.com   98947185431         1
# 499999  499999                       880053388839         0
#
#                           OrderId
# 0
# 1       vDDJJcxfLtSfkooPhbYnJdxov
# 2
# 3       bHquEnCbbsGLqllwryxPsNOxa
# 4
# ...                           ...
# 499995  whJlUOGNqjxCRzmIRdURQvlNv
# 499996  JqIXOONvrwvJxZqNxCYHqnrKS
# ...

# %%
df

# %%
df_orderid = df['OrderId'].unique()
df_orderid
# Out:
# array(['', 'vDDJJcxfLtSfkooPhbYnJdxov', 'bHquEnCbbsGLqllwryxPsNOxa', ...,
#        'JqIXOONvrwvJxZqNxCYHqnrKS', 'beXCZSzcHaBwAYoDcpQqjuAFO',
#        'JibSBRgzYdfzkzbTuGUXrcvDX'], dtype=object)

# %%
df_orderid.size
# Out:
# 189303

# %%
# Out:
#             Id                        Email         Phone  Contacts  \
# 1            1                               329442681752         4
# 2458      2458         ULziZaVD@hotmail.com     069988936         1
# 476346  476346  WXJDcOYGapCzchhwH@gmail.com                       0
#
#                           OrderId
# 1       vDDJJcxfLtSfkooPhbYnJdxov
# 2458    vDDJJcxfLtSfkooPhbYnJdxov
# 476346  vDDJJcxfLtSfkooPhbYnJdxov

# %%
orderid = 'vDDJJcxfLtSfkooPhbYnJdxov'
dfOrderId = df[df['OrderId'] == orderid]['Id'].to_numpy()
dict(orderid = dfOrderId)
# Out:
# {'vDDJJcxfLtSfkooPhbYnJdxov': array([     1,   2458, 476346], dtype=int64)}

# %%
dfOrderId
# Out:
# {'orderid': array([     1,   2458, 476346], dtype=int64)}

# %%
dictOrderId = df.groupby('OrderId')['Id'].apply(list).to_dict()
del dictOrderId['']
# dictOrderId
len(dictOrderId)
# dictOrderId.pop('vDDJJcxfLtSfkooPhbYnJdxov', None)
# Out:
# 189302

# %%
dictEmail = df.groupby('Email')['Id'].apply(list).to_dict()
del dictEmail['']
dictEmail
# Out:
# {'AAAQbNfGbLAeOvw@hotmail.com': [112387, 470075],
#  'AAAgyKTteOjasN@qq.com': [338154],
#  'AABZmKeEldvO@gmail.com': [426495],
#  'AABneiGcqcz@qq.com': [37868],
#  'AABtOIZmdYdKGnidAK@yahoo.com': [137956],
#  'AADMnHjRAVJ@yahoo.com': [494574],
#  'AADMsTZAxsOHvqnKjg@hotmail.com': [19504, 179125],
#  'AAEdstsQlG@gmail.com': [299505],
#  'AAFCdSUDpTu@hotmail.com': [299171],
#  'AAFsFMAfPCS@qq.com': [386346],
#  'AAFtcxPyCNETUZuVq@yahoo.com': [99859],
#  'AAHGdVxWJVRtKOSdgHKV@qq.com': [326760],
#  'AAHjYELrfgvjqCoZ@hotmail.com': [76239],
#  'AAHmiENRMnmAvRqFNKe@qq.com': [462902],
#  'AAIXcxIAYhn@hotmail.com': [487374],
#  'AAJboPehjAJajqxGPrjn@hotmail.com': [87543],
#  'AAJcFFDgfLHBkDrXoaDx@yahoo.com': [20825, 337532],
#  'AAKUqaw@hotmail.com': [305394],
#  'AALsQhEpZeeDsn@gmail.com': [362],
#  'AANxrVHcdxIrc@qq.com': [153039],
#  'AAOPaYMogBRr@gmail.com': [221848, 330517],
#  'AAPIPtjhTqBsjvnutTU@hotmail.com': [254424, 367012, 390060],
#  'AAPxNUW@hotmail.com': [214212],
# ...

# %%
dictPhone = df.groupby('Phone')['Id'].apply(list).to_dict()
del dictPhone['']
len(dictPhone)
# Out:
# 190677

# %%
3 dict -email, phone, orderid

1. email
loop 0-500rb
idx
for key in dict.keys
array A = dictemail(key) 
if idx in array A
array_temp = array_temp + array A
array_temp.unique
tickettracece_dict key = idx, value = array_temp


phone
# Out:
#   File "<ipython-input-97-7ba411a6b89d>", line 1
#     3 array -email, phone, orderid
#       ^
# SyntaxError: invalid syntax

# %%
ticketTrace_dict = {}
for idx in range (0,500000) :
    for key in dictOrderId.keys():
        array_temp = []
        list_key = list(dictOrderId[key])
        if idx in list_key:
            array_temp + list_key
            for df['contacts']
#             array_temp = list( dict.fromkeys(array_temp))
            ticketTrace_dict[idx] = array_temp
# Out:
#   File "<ipython-input-176-acce8befbbe9>", line 8
#     for
#         ^
# SyntaxError: invalid syntax

# %%
ticketTrace_dict = {}
for key in dictOrderId.keys():
        array_temp = []
        list_ticket = list(dictOrderId[key])
        for ticket in list_ticket:
            array_temp = array_temp + list_ticket
            array_temp = list(dict.fromkeys(array_temp))
            ticketTrace_dict[ticket] = array_temp
            
for key in dictEmail.keys():
        array_temp = []
        list_ticket = list(dictEmail[key])
        for ticket in list_ticket:
            array_temp = array_temp + list_ticket
            array_temp = list(dict.fromkeys(array_temp))
            ticketTrace_dict[ticket] = array_temp
            
for key in dictPhone.keys():
        array_temp = []
        list_ticket = list(dictPhone[key])
        for ticket in list_ticket:
            array_temp = array_temp + list_ticket
            array_temp = list(dict.fromkeys(array_temp))
            ticketTrace_dict[ticket] = array_temp

# %%
ticketTrace_dict
# Out:
# {445646: [90335, 441207, 445646],
#  143711: [143711, 321395],
#  494384: [494384],
#  442033: [442033],
#  189835: [189835],
#  13086: [13086],
#  35886: [35886],
#  258835: [234716, 258835, 449459],
#  217525: [201856, 217525, 315328],
#  222796: [222796],
#  488624: [488624],
#  212727: [74574, 146653, 212727],
#  361700: [16752, 361700],
#  454292: [179935, 454292],
#  81058: [81058, 399588],
#  28176: [28176],
#  51827: [51827, 301903],
#  255333: [255333],
#  338630: [189100, 338630],
#  401880: [401880],
#  436322: [436322],
#  374118: [374118],
#  233329: [233329],
#  78382: [78382],
#  330665: [330665],
#  207118: [207118],
#  421418: [421418],
#  68035: [68035],
#  106903: [106903],
#  133432: [133432],
#  411122: [206175, 411122],
#  233420: [2210, 233420],
#  465861: [361023, 465861],
#  63802: [63802, 306178],
#  99906: [99906],
#  208540: [208540],
#  67622: [36632, 67622, 412415],
#  484961: [484961],
#  390896: [390896],
#  104302: [104302],
# ...

# %%
ticketTrace_dict_final = {}
for key in ticketTrace_dict.keys():
    list_ticket = list(ticketTrace_dict[key])
    count = 0
    if len(list_ticket) > 0:
        my_string = '-'.join(map(str, list_ticket)) 
        for ticket in list_ticket:
            contacts = df[df['Id'] == 0].Contacts.values[0]
            count = count + contacts
    else :
        my_string = list_ticket
        contacts = df[df['Id'] == 0].Contacts.values[0]
        count = count + contacts
    my_string = my_string + ", " + str(count)
    
    ticketTrace_dict_final[key] = my_string

# %%
ticketTrace_dict_final = {}
for key in ticketTrace_dict.keys():
    list_ticket = list(ticketTrace_dict[key])
    count = 0
    if len(list_ticket) > 0:
        my_string = '-'.join(map(str, list_ticket)) 
    else :
        my_string = list_ticket
    
    ticketTrace_dict_final[key] = my_string

# %%
ticketTrace_dict_final
# Out:
# {445646: '90335-441207-445646',
#  143711: '143711-321395',
#  494384: '494384',
#  442033: '442033',
#  189835: '189835',
#  13086: '13086',
#  35886: '35886',
#  258835: '234716-258835-449459',
#  217525: '201856-217525-315328',
#  222796: '222796',
#  488624: '488624',
#  212727: '74574-146653-212727',
#  361700: '16752-361700',
#  454292: '179935-454292',
#  81058: '81058-399588',
#  28176: '28176',
#  51827: '51827-301903',
#  255333: '255333',
#  338630: '189100-338630',
#  401880: '401880',
#  436322: '436322',
#  374118: '374118',
#  233329: '233329',
#  78382: '78382',
#  330665: '330665',
#  207118: '207118',
#  421418: '421418',
#  68035: '68035',
#  106903: '106903',
#  133432: '133432',
#  411122: '206175-411122',
#  233420: '2210-233420',
#  465861: '361023-465861',
#  63802: '63802-306178',
#  99906: '99906',
#  208540: '208540',
#  67622: '36632-67622-412415',
#  484961: '484961',
#  390896: '390896',
#  104302: '104302',
#  214227: '214227-382495',
# ...

# %%
df_final = pd.DataFrame.from_dict(ticketTrace_dict_final, orient='index',
                       columns=['tic', 'ticket_trace/contact'])
pd.DataFrame.from_dict(data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-208-fb46d0180e9a> in <module>
# ----> 1 df_final = pd.DataFrame.from_dict(ticketTrace_dict_final)
#
# D:\anaconda3\lib\site-packages\pandas\core\frame.py in from_dict(cls, data, orient, dtype, columns)
#    1307             raise ValueError("only recognize index or columns for orient")
#    1308
# -> 1309         return cls(data, index=index, columns=columns, dtype=dtype)
#    1310
#    1311     def to_numpy(
#
# D:\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     466
#     467         elif isinstance(data, dict):
# --> 468             mgr = init_dict(data, index, columns, dtype=dtype)
#     469         elif isinstance(data, ma.MaskedArray):
#     470             import numpy.ma.mrecords as mrecords
#
# ...

# %%
contacts = df[df['Id'] == 0].Contacts.values[0]
contacts
# Out:
# 1
